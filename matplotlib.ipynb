# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('시군구별_이동자수_20220216221103.xlsx',header = 0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.isna().sum()
# Out:
# 행정구역(시군구)별    0
# 2018. 02      0
# 2018. 03      0
# 2018. 04      0
# 2018. 05      0
# 2018. 06      0
# 2018. 07      0
# 2018. 08      0
# 2018. 09      0
# 2018. 10      0
# 2018. 11      0
# 2018. 12      0
# 2019. 01      0
# 2019. 02      0
# 2019. 03      0
# 2019. 04      0
# 2019. 05      0
# 2019. 06      0
# 2019. 07      0
# 2019. 08      0
# 2019. 09      0
# 2019. 10      0
# 2019. 11      0
# 2019. 12      0
# 2020. 01      0
# 2020. 02      0
# 2020. 03      0
# 2020. 04      0
# 2020. 05      0
# 2020. 06      0
# 2020. 07      0
# 2020. 08      0
# 2020. 09      0
# 2020. 10      0
# 2020. 11      0
# 2020. 12      0
# 2021. 01      0
# 2021. 02      0
# 2021. 03      0
# 2021. 04      0
# 2021. 05      0
# 2021. 06      0
# 2021. 07      0
# 2021. 08      0
# 2021. 09      0
# 2021. 10      0
# 2021. 11      0
# 2021. 12      0
# dtype: int64

# %%
df
# Out:
#    행정구역(시군구)별  2018. 02  2018. 03  2018. 04  2018. 05  2018. 06  2018. 07  \
# 0  행정구역(시군구)별   총전입 (명)   총전입 (명)   총전입 (명)   총전입 (명)   총전입 (명)   총전입 (명)
# 1          전국  697706.0  707829.0  593767.0  599570.0  543797.0  568604.0
# 2       서울특별시  135440.0  144160.0  117443.0  117278.0  109139.0  112580.0
# 3       부산광역시   39119.0   42516.0   34794.0   37839.0   31839.0   33669.0
# 4       대구광역시   30043.0   28106.0   24869.0   27231.0   25197.0   24368.0
# 5       인천광역시   43227.0   43841.0   37290.0   36824.0   32648.0   32372.0
# 6       광주광역시   19797.0   20144.0   17070.0   17926.0   16660.0   17701.0
# 7       대전광역시   20144.0   19083.0   16239.0   17019.0   16263.0   18149.0
# 8       울산광역시   13003.0   12100.0   10358.0   10575.0    9605.0   10120.0
#
#    2018. 08  2018. 09  2018. 10  ...  2021. 03  2021. 04  2021. 05  2021. 06  \
# 0   총전입 (명)   총전입 (명)   총전입 (명)  ...   총전입 (명)   총전입 (명)   총전입 (명)   총전입 (명)
# ...

# %%
df_year = df.columns[1:]

# %%
df_seoul = df.values[2][1:]
df_busan = df.values[3][1:]
df_degu = df.values[4][1:]
df_incheon = df.values[5][1:]

# %%
df_seoul
# Out:
# array([135440.0, 144160.0, 117443.0, 117278.0, 109139.0, 112580.0,
#        117300.0, 92262.0, 132111.0, 125350.0, 117524.0, 128937.0,
#        146401.0, 135592.0, 118129.0, 110881.0, 91828.0, 111288.0,
#        110592.0, 103969.0, 128067.0, 113012.0, 127797.0, 131105.0,
#        170587.0, 164402.0, 127208.0, 117734.0, 122292.0, 115625.0,
#        123804.0, 127908.0, 126788.0, 117563.0, 133111.0, 114415.0,
#        141936.0, 151617.0, 117475.0, 112967.0, 104704.0, 111646.0,
#        125161.0, 110490.0, 107123.0, 108106.0, 112547.0], dtype=object)

# %%
df_year
# Out:
# Index(['2018. 02', '2018. 03', '2018. 04', '2018. 05', '2018. 06', '2018. 07',
#        '2018. 08', '2018. 09', '2018. 10', '2018. 11', '2018. 12', '2019. 01',
#        '2019. 02', '2019. 03', '2019. 04', '2019. 05', '2019. 06', '2019. 07',
#        '2019. 08', '2019. 09', '2019. 10', '2019. 11', '2019. 12', '2020. 01',
#        '2020. 02', '2020. 03', '2020. 04', '2020. 05', '2020. 06', '2020. 07',
#        '2020. 08', '2020. 09', '2020. 10', '2020. 11', '2020. 12', '2021. 01',
#        '2021. 02', '2021. 03', '2021. 04', '2021. 05', '2021. 06', '2021. 07',
#        '2021. 08', '2021. 09', '2021. 10', '2021. 11', '2021. 12'],
#       dtype='object')

# %%
plt.plot(df_year,df_seoul)

# %%
## 차트 이름 제목 추가
## 한글 폰트
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.plot(df_year,df_seoul)
plt.title('서울시 전입 인구')
plt.xlabel('기간')
# Out:
# Text(0.5, 0, '기간')

# %%
## 글자 겹치지 않게 하기
plt.figure(figsize=(14,5))
plt.plot(df_year,df_seoul)

## 글자 회전
plt.xticks(rotation='vertical')
plt.plot(df_year,df_seoul)
plt.title('서울시 전입 인구')
plt.xlabel('기간')
# Out:
# Text(0.5, 0, '기간')

# %%
## 스타일 서식
plt.style.use('ggplot')

## 마커 표시
plt.figure(figsize=(14,5))
plt.plot(df_year,df_seoul,marker='o', markersize = 5)
plt.xticks(rotation='vertical')
plt.title('서울시 전입 인구')
plt.xlabel('기간')
## label
plt.legend(labels = ['서울 전입 인구'],loc='best')

# %%
### 여러항목 표시
## 스타일 서식
plt.style.use('ggplot')

## 마커 표시
plt.figure(figsize=(14,5))
plt.plot(df_year,df_seoul,marker='o', markersize = 5,label = '서울')
plt.plot(df_year,df_busan,marker='o', markersize = 5,label = '부산')
plt.plot(df_year,df_degu,marker='o', markersize = 5,label = '대구')
plt.plot(df_year,df_incheon,marker='o', markersize = 5,label = '인천')
plt.xticks(rotation='vertical')
plt.title('광역시 전입 인구')
plt.xlabel('기간')
## label
plt.legend(loc="best")

# %%
df = df.drop(index=0, axis=0)

# %%
df = df.drop(index=1, axis=0)

# %%
df
# Out:
#   행정구역(시군구)별  2018. 02  2018. 03  2018. 04  2018. 05  2018. 06  2018. 07  \
# 2      서울특별시  135440.0  144160.0  117443.0  117278.0  109139.0  112580.0
# 3      부산광역시   39119.0   42516.0   34794.0   37839.0   31839.0   33669.0
# 4      대구광역시   30043.0   28106.0   24869.0   27231.0   25197.0   24368.0
# 5      인천광역시   43227.0   43841.0   37290.0   36824.0   32648.0   32372.0
# 6      광주광역시   19797.0   20144.0   17070.0   17926.0   16660.0   17701.0
# 7      대전광역시   20144.0   19083.0   16239.0   17019.0   16263.0   18149.0
# 8      울산광역시   13003.0   12100.0   10358.0   10575.0    9605.0   10120.0
#
#    2018. 08 2018. 09  2018. 10  ...  2021. 03  2021. 04  2021. 05  2021. 06  \
# 2  117300.0  92262.0  132111.0  ...  151617.0  117475.0  112967.0  104704.0
# 3   33825.0  25264.0   35078.0  ...   42381.0   36090.0   37416.0   34889.0
# 4   25783.0  22128.0   29869.0  ...   30967.0   25138.0   22295.0   21466.0
# 5   31146.0  24293.0   36525.0  ...   40378.0   35108.0   35563.0   34461.0
# ...

# %%
df = df.transpose()

# %%
df = df.rename(columns=df.iloc[0]).drop(df.index[0])

# %%
df.head()
# Out:
#              서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시    울산광역시
# 2018. 02  135440.0  39119.0  30043.0  43227.0  19797.0  20144.0  13003.0
# 2018. 03  144160.0  42516.0  28106.0  43841.0  20144.0  19083.0  12100.0
# 2018. 04  117443.0  34794.0  24869.0  37290.0  17070.0  16239.0  10358.0
# 2018. 05  117278.0  37839.0  27231.0  36824.0  17926.0  17019.0  10575.0
# 2018. 06  109139.0  31839.0  25197.0  32648.0  16660.0  16263.0   9605.0

# %%
## 면적 그래프
df.plot(kind='area', stacked=False,figsize = (20,10),alpha = 0.3)
plt.title('광역시 전입 인구')
plt.xlabel('기간')
# Out:
# Text(0.5, 0, '기간')

# %%
df.plot(kind='area', stacked=True,figsize = (20,10),alpha = 0.3)  ## alpha = 투명도
plt.title('광역시 전입 인구')
plt.xlabel('기간')
##  stacked=True == 데이터 겹치지 않음
# Out:
# Text(0.5, 0, '기간')

# %% [markdown]
# 막대 그래프

# %%
df.plot(kind='bar',figsize=(30,10),width=0.7)
# Out:
# <AxesSubplot:>

# %%
df1 = df.transpose()
df1['합계'] = df1.sum(axis=1)
df1_total = df1[['합계']].sort_values(by='합계',ascending=True)
plt.style.use('ggplot')
df1_total.plot(kind='barh',color='skyblue',figsize=(10,5))
plt.title('전국 전입 인구')
plt.ylabel('전입지')
plt.xlabel('전입 인구 수')
# Out:
# Text(0.5, 0, '전입 인구 수')

# %%
from tensorflow import keras
dataset_path = keras.utils.get_file("auto-mpg.data", "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")

# %%
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']
raw_dataset = pd.read_csv(dataset_path, names=column_names,
                      na_values = "?", comment='\t',
                      sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()

# %%
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %% [markdown]
# 히스토그램

# %%
plt.rcParams['font.family'] = 'gulim.ttc'
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('classic')
dataset['MPG'].plot(kind='hist',bins=10,color='orange',figsize=(10,5))
plt.title('hist')
plt.xlabel('MPG')
# Out:
# Text(0.5, 0, 'MPG')

# %% [markdown]
# 산점도

# %%
plt.style.use('default')
dataset.plot(kind='scatter',x='Weight',y = 'MPG',c='coral',s=10,figsize=(10,5))
plt.title('scatter')
# Out:
# Text(0.5, 1.0, 'scatter')

# %%
##변수 3개로 산점도 그리기
cylinder_size = dataset.Cylinders/dataset.Cylinders.max()*300
dataset.plot(kind='scatter',x='Weight',y = 'MPG',c='blue',s=cylinder_size,figsize=(10,5),alpha=0.2)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='MPG'>

# %%
## 모양바꾸기
cylinder_size = dataset.Cylinders/dataset.Cylinders.max()*300
dataset.plot(kind='scatter',x='Weight',y = 'MPG',c=cylinder_size,s=50,figsize=(10,5),alpha=0.2,marker='x',cmap='viridis')
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='MPG'>

# %%
## 파이차트
dataset['count'] = 1
df_origin = dataset.groupby('Origin').sum()
df_origin
# Out:
#            MPG  Cylinders  Displacement  Horsepower    Weight  Acceleration  \
# Origin
# 1       5000.8       1556       61229.5     29167.0  837121.0        3743.4
# 2       1952.4        291        7640.0      5478.0  169631.0        1175.1
# 3       2405.6        324        8114.0      6307.0  175477.0        1277.6
#
#         Model Year  count
# Origin
# 1            18827    249
# 2             5307     70
# 3             6118     79

# %%
df_origin.index = ['USA','EU','JPN']
df_origin
# Out:
#         MPG  Cylinders  Displacement  Horsepower    Weight  Acceleration  \
# USA  5000.8       1556       61229.5     29167.0  837121.0        3743.4
# EU   1952.4        291        7640.0      5478.0  169631.0        1175.1
# JPN  2405.6        324        8114.0      6307.0  175477.0        1277.6
#
#      Model Year  count
# USA       18827    249
# EU         5307     70
# JPN        6118     79

# %%
df_origin['count'].plot(kind='pie',figsize=(7,5),autopct='%1.1f%%',##퍼센트 페이지 표시
                       startangle=10,## 파이 각도 표시
                       )
# Out:
# <AxesSubplot:ylabel='count'>

# %%
## 박스차트
plt.style.use('seaborn-poster')
plt.rcParams['axes.unicode_minus'] = False

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2= fig.add_subplot(1,2,2)

ax1.boxplot(x=[dataset[dataset['Origin']==1]['MPG'],
              dataset[dataset['Origin']==2]['MPG'],
              dataset[dataset['Origin']==3]['MPG']],
           labels = ['USA','EU','JAPAN'])
ax2.boxplot(x=[dataset[dataset['Origin']==1]['MPG'],
              dataset[dataset['Origin']==2]['MPG'],
              dataset[dataset['Origin']==3]['MPG']],
           labels = ['USA','EU','JAPAN'],
           vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18be7df2ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18be7df2160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18be7df8640>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x18be7df2220>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x18be7de3820>,
# ...
#  'means': []}
